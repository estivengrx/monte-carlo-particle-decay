# %%
from particle import Particle

mu = Particle.from_name("mu-")
print(mu.describe())
# Out:
# Name: mu-            ID: 13           Latex: $\mu^{-}$
# Mass  = 105.6583755 ± 0.0000023 MeV
# Lifetime = 2196.9812 ± 0.0022 ns
# Q (charge)        = -       J (total angular) = 0.5      P (space parity) = None
# C (charge parity) = None    I (isospin)       = None     G (G-parity)     = None
#     SpinType: 5
#     Antiparticle name: mu+ (antiparticle status: ChargeInv)
